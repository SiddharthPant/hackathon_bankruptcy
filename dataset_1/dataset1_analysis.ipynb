# %%
# %load /home/sid/libs.txt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
names = ['account_status', 'duration', 'credit_history', 'purpose', 'credit_amount', 'saving_accounts', 'employed', 'installment', 'personal_status_sex', 'debtors', 'present_residence', 'property', 'age', 'plans', 'housing', 'existing_credits', 'job', 'people_for_matintenance', 'telephone', 'foreign_worker','x1']
names2 = names + ['indicator1', 'indicator2', 'indicator3', 'indicator4']

# %%
ds1 = pd.read_csv("german.data", delimiter=" ", names=names)

# %%
ds1.head()
# Out:
#   account_status  duration credit_history purpose  credit_amount  \
# 0            A11         6            A34     A43           1169
# 1            A12        48            A32     A43           5951
# 2            A14        12            A34     A46           2096
# 3            A11        42            A32     A42           7882
# 4            A11        24            A33     A40           4870
#
#   saving_accounts employed  installment personal_status_sex debtors ...  \
# 0             A65      A75            4                 A93    A101 ...
# 1             A61      A73            2                 A92    A101 ...
# 2             A61      A74            2                 A93    A101 ...
# 3             A61      A74            2                 A93    A103 ...
# 4             A61      A73            3                 A93    A101 ...
#
#    property age  plans housing existing_credits   job people_for_matintenance  \
# ...

# %%
ds1n = pd.read_csv('german_edited.data-numeric', names=names2 + ['x1', delimiter=' ')

# %%
ds1n.head()
# Out:
#    account_status  duration  credit_history  purpose  credit_amount  \
# 1               6         4              12        5              5
# 2              48         2              60        1              3
# 4              12         4              21        1              4
# 1              42         2              79        1              4
# 1              24         3              49        1              3
#
#    saving_accounts  employed  installment  personal_status_sex  debtors  \
# 1                3         4            1                   67        3
# 2                2         2            1                   22        3
# 4                3         3            1                   49        3
# 1                3         4            2                   45        3
# 1                3         4            4                   53        3
#
#       ...      existing_credits  job  people_for_matintenance  telephone  \
# ...
